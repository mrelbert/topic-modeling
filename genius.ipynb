# %%
import os
import json
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import lyricsgenius as lg

# %env GENIUS_ACCESS_TOKEN=H5JHPJZrJ-cK704dbMbmeQA0E6DZ8T5DZneDvnOvvhCdBX9I-wLPkrLGkxOIeAU2
# Out:
# env: GENIUS_ACCESS_TOKEN=H5JHPJZrJ-cK704dbMbmeQA0E6DZ8T5DZneDvnOvvhCdBX9I-wLPkrLGkxOIeAU2

# %%
access_token = os.environ['GENIUS_ACCESS_TOKEN']
genius = lg.Genius(access_token)

# %%
artist = genius.search_artist("J Cole")
# Out:
# Searching for songs by J Cole...
#
# Changing artist name to 'J. Cole'
# Song 1: "No Role Modelz"
# Song 2: "Power Trip"
# Song 3: "Wet Dreamz"
# Song 4: "Crooked Smile"
# Song 5: "MIDDLE CHILD"
# Song 6: "Deja Vu"
# Song 7: "Love Yourz"
# Song 8: "G.O.M.D."
# Song 9: "Apparently"
# Song 10: "Kevin’s Heart"
# Song 11: "Fire Squad"
# Song 12: "KOD"
# Song 13: "4 Your Eyez Only"
# Song 14: "1985"
# Song 15: "A Tale of 2 Citiez"
# Song 16: "Neighbors"
# Song 17: "She Knows"
# Song 18: "03' Adolescence"
# Song 19: "Forbidden Fruit"
# Song 20: "Immortal"
# Song 21: "Work Out"
# Song 22: "Rich Niggaz"
# Song 23: "ATM"
# Song 24: "Change"
# Song 25: "January 28th"
# Song 26: "Let Nas Down"
# Song 27: "Nobody’s Perfect"
# Song 28: "False Prophets"
# Song 29: "Villuminati"
# Song 30: "She’s Mine, Pt. 1"
# Song 31: "Born Sinner"
# Song 32: "In the Morning"
# Song 33: "Snow on tha Bluff"
# Song 34: "​everybody dies"
# Song 35: "Lost Ones"
# Song 36: "Photograph"
# Song 37: "Runaway"
# ...

# %%
artist.save_lyrics()
# Out:
# Lyrics_J.Cole.json already exists. Overwrite?
# (y/n):  y
# Wrote `Lyrics_J.Cole.json`

# %%
with open('./Lyrics_J.Cole.json') as json_file:
    data = json.load(json_file)
    
    master_list = []
    for song in data['songs']:
        temp_dict = {}
        
        try:
            temp_dict['title'] = song['title']
        except:
            temp_dict['title'] = None
            
        try:
            temp_dict['release_date'] = song['release_date']
        except:
            temp_dict['release_date'] = None
            
        try:
            temp_dict['album_name'] = song['album']['name']
        except: 
            temp_dict['album_name'] = None
            
        try:
            temp_dict['lyrics_state'] = song['lyrics_state']
        except:
            temp_dict['lyrics_state'] = None
            
        try:
            temp_dict['lyrics'] = song['lyrics']
        except:
            temp_dict['lyrics'] = None
            
        master_list.append(temp_dict)

# %%
df = pd.DataFrame(master_list)

# %%
albums = df.dropna(subset=['album_name'])

# %%
albums['album_name'].value_counts()
# Out:
# The Warm Up                                       22
# The Come Up Vol. 1 Mixtape                        21
# Born Sinner (Deluxe Version)                      19
# Friday Night Lights                               19
# Cole World: The Sideline Story                    17
# 2014 Forest Hills Drive                           13
# Forest Hills Drive: Live from Fayetteville, NC    13
# KOD                                               12
# 4 Your Eyez Only                                  10
# Truly Yours 2                                      5
# Any Given Sunday #1                                5
# Revenge of the Dreamers                            5
# Truly Yours                                        5
# Any Given Sunday #2                                3
# Lewis Street                                       2
# Revenge of the Dreamers II                         2
# Any Given Sunday #5                                2
# The Xaphoon Jones Mixtape Vol. 2                   1
# ...

# %%
warm_up = df.loc[df['album_name'] == 'The Warm Up']

# %%
foresthills = df.loc[df['album_name'] == '2014 Forest Hills Drive']

# %%
kod = df.loc[df['album_name'] == 'KOD']

# %%
eyezonly = df.loc[df['album_name'] == '4 Your Eyez Only']

# %%
lewis = df.loc[df['album_name'] == 'Lewis Street']

# %%
bs = df.loc[df['album_name'] == 'Born Sinner (Deluxe Verseion)']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
stop_words_list = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "
ve", "ve", "very", "via", "viz", "vj", "vo", "vol", "vols", "volumtype", "vq", "vs", "vt", "vu", "w", "wa", "want", "wants", "was", "wasn", "wasnt", "wasn't", "way", "we", "wed", "we'd", "welcome", "well", "we'll", "well-b", "went", "were", "we're", "weren", "werent", "weren't", "we've", "what", "whatever", "what'll", "whats", "what's", "when", "whence", "whenever", "when's", "where", "whereafter", "whereas", "whereby", "wherein", "wheres", "where's", "whereupon", "wherever", "whether", "which", "while", "whim", "whither", "who", "whod", "whoever", "whole", "who'll", "whom", "whomever", "whos", "who's", "whose", "why", "why's", "wi", "widely", "will", "willing", "wish", "with", "within", "without", "wo", "won", "wonder", "wont", "won't", "words", "world", "would", "wouldn", "wouldnt", "wouldn't", "www", "x", "x1", "x2", "x3", "xf", "xi", "xj", "xk", "xl", "xn", "xo", "xs", "xt", "xv", "xx", "y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "you'd", "you'll", "your", "youre", "you're", "yours", "yourself", "yourselves", "you've", "yr", "ys", "yt", "z", "zero", "zi", "zz"]

# %%
vectorizer = TfidfVectorizer(min_df=0.1, stop_words=stop_words_list)
X = vectorizer.fit_transform(lewis['lyrics'])

n_topics = 5
# nmf - 'random state' parameter ?
nmf = NMF(n_components=n_topics, random_state=1).fit(X)

# Print the top 10 words
n_words = 10
feature_names = vectorizer.get_feature_names()

topic_list = []
for topic_idx, topic in enumerate(nmf.components_):
    top_n = [feature_names[i]
             for i in topic.argsort()
             [-n_words:]][::-1]
    top_features = ' '.join(top_n)
    topic_list.append(f"topic_{'_'.join(top_n[:3])}") 

    print(f"Topic {topic_idx}: {top_features}")
    
# warm up
# Topic 0: yeah niggas shit nigga money fucking deal dream dollar hey
# Topic 1: yea nigga trynna warm uh hold niggas chill shit love
# Topic 2: good ladies girl cole dreams hey aye gon hook day
# Topic 3: feel devil life yeah long coming guess pain warm heart
# Topic 4: live son niggas gon momma nigga gotta hope sun shit

# forest hills
# Topic 0: nigga man hands shit fuck air yeah start love niggas
# Topic 1: wanna free happy hoes time ayy pussy chorus bitch pre
# Topic 2: paid hollywood bout smile hard hook reason stay singing sample
# Topic 3: thought sad lookin things shit kid forever today wait chorus
# Topic 4: nigga thing gon love niggas life high chorus tune rap

# kod
# Topic 0: wanna man alive money niggas feelin gon respect yo shit
# Topic 1: yeah shoot shot brick heart shit nigga hell niggas lord
# Topic 2: choose wisely pain hold deal mama ways god bring head
# Topic 3: smoke die bag edward today mind chorus comin kill cloud
# Topic 4: flip brick whip keys mama hard shit drug crazy fuck

# 4 your eyez only
# Topic 0: real niggas eyes cole nigga change understand form inside die
# Topic 1: catch felt alive thinking wanna shit bout fallen dry love
# Topic 2: things long mentality survive dirt clothes fold wanna fore disappear
# Topic 3: sellin dope neighbors follow guess motherfucker south thinkin integration fortune
# Topic 4: pouring bells lord rain surprise louder loud hide high low

# lewis street
# Topic 0: gon niggas gotta nigga real shoes god chorus long verse
# Topic 1: niggas nigga gotta dead gon pick pleasant smile red lies
# Topic 2: lie hands big gon prove plans lot mud nothin blood
# Topic 3: niggas hurtful fore lost number lay prevention triggers sun city
# Topic 4: niggas dead breath nigga town shift pole circle mines bet
# Out:
# Topic 0: gon niggas gotta nigga real shoes god chorus long verse
# Topic 1: niggas nigga gotta dead gon pick pleasant smile red lies
# Topic 2: lie hands big gon prove plans lot mud nothin blood
# Topic 3: niggas hurtful fore lost number lay prevention triggers sun city
# Topic 4: niggas dead breath nigga town shift pole circle mines bet
# /Users/scraper/miniconda3/envs/jcole/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['articl', 'mon'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
warm_up_tfidfvect = pd.DataFrame(data = X.toarray(), columns=warmup_tokens)
warm_up_tfidfvect
# Out:
#        about    acting       ago       ain       all     alone    always  \
# 0   0.062284  0.000000  0.051870  0.030875  0.146067  0.000000  0.044220
# 1   0.014642  0.000000  0.000000  0.019355  0.021131  0.000000  0.020791
# 2   0.021368  0.035590  0.000000  0.169480  0.061676  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.061106  0.016678  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.025337  0.027662  0.000000  0.000000
# 5   0.015606  0.000000  0.000000  0.123778  0.045044  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.055774  0.012178  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.122470  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.056213  0.000000  0.000000  0.000000  0.095845
# 9   0.000000  0.000000  0.000000  0.021546  0.117612  0.054295  0.000000
# 10  0.000000  0.000000  0.000000  0.018893  0.020626  0.000000  0.000000
# 11  0.012184  0.000000  0.020293  0.169115  0.035168  0.000000  0.000000
# ...

# %%
print(vectorizer.get_feature_names())
# Out:
# ['about', 'all', 'are', 'as', 'ass', 'at', 'ay', 'baby', 'back', 'be', 'been', 'better', 'bitch', 'blow', 'bout', 'boy', 'broke', 'by', 'came', 'cause', 'chorus', 'city', 'cole', 'come', 'could', 'couldn', 'damn', 'deep', 'did', 'do', 'dog', 'don', 'down', 'dream', 'em', 'even', 'ever', 'feel', 'from', 'fuck', 'fucking', 'game', 'get', 'girl', 'give', 'go', 'god', 'gon', 'good', 'gotta', 'guess', 'had', 'hard', 'have', 'he', 'head', 'hear', 'heard', 'hell', 'her', 'here', 'hey', 'high', 'his', 'hit', 'hoes', 'hold', 'home', 'hook', 'how', 'if', 'intro', 'just', 'keep', 'let', 'life', 'little', 'll', 'look', 'lord', 'love', 'make', 'man', 'mind', 'more', 'name', 'need', 'never', 'niggas', 'no', 'not', 'now', 'off', 'oh', 'okay', 'one', 'only', 'or', 'other', 'out', 'outro', 'over', 'play', 'probably', 'put', 'rap', 'real', 'right', 'said', 'same', 'say', 'see', 'seen', 'she', 'shit', 'show', 'some', 'stay', 'still', 'stop', 'straight', 'take', 'tell', 'than', 'them', 'then', 'there', 
# ...
